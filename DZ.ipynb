# %% [markdown]
# ### **Тест по SQLAlchemy**
#
# #### **1. Какой из следующих подходов используется в SQLAlchemy для определения модели таблицы?**
# a) Классический метод определения через ORM
# b) <u>Декларативный метод </u>
# c) SQL Core метод
# d) Все вышеперечисленные
#
# ---
#
# #### **2. Что обозначает `__tablename__` в модели SQLAlchemy?**
# a) Название базы данных, с которой связывается модель
# b) <u>Название таблицы, соответствующей данной модели</u>
# c) Название столбца, используемого для первичного ключа
# d) Название атрибута, который содержит уникальные значения
#
# ---
#
# #### **3. Какой метод используется для добавления новой записи в базу данных через SQLAlchemy ORM?**
# a) <u>`session.commit()`</u>
# b) `session.add()`
# c) `session.execute()`
# d) `session.save()`
#
# ---
#
# #### **4. Что делает `session.query()` в SQLAlchemy?**
# a) Создает новый объект таблицы
# b) <u>Позволяет строить SQL-запросы через ORM</u>
# c) Автоматически создает индексы в базе данных
# d) Удаляет данные из таблицы
#
# ---
#
# #### **5. Какой тип связи задается в SQLAlchemy с помощью `relationship()`?**
# a) Один-к-одному
# b) Один-ко-многим
# c) Многие-ко-многим
# d) <u>Все вышеперечисленные</u>
#
# ---
#
# #### **6. Какой параметр `Column` используется для определения первичного ключа?**
# a) <u>`primary_key=True`</u>
# b) `index=True`
# c) `unique=True`
# d) `nullable=False`
#
# ---
#
# #### **7. Какое преимущество дает использование `lazy='joined'` в `relationship()`?**
# a) <u>Ускоряет выполнение запросов за счет подгрузки данных сразу</u>
# b) Позволяет создавать связи между таблицами
# c) Автоматически создает индексы
# d) Уменьшает объем загружаемых данных
#
# ---
#
# #### **8. Как включить логирование SQL-запросов в SQLAlchemy?**
# a) <u>Добавить `echo=True` при создании `engine`</u>
# b) Использовать метод `session.enable_logging()`
# c) Установить переменную окружения `SQL_LOGGING=True`
# d) Использовать декоратор `@enable_sql_logging`
#
# ---
#
# #### **9. Какой модуль нужен для работы с асинхронным SQLAlchemy в FastAPI?**
# a) <u>`asyncpg`</u>
# b) `sqlalchemy.asyncio`
# c) `databases`
# d) Все вышеперечисленные
#
# ---
#
# #### **10. Какой метод используется для завершения работы с сессией?**
# a) <u>`session.close()`</u>  SQLAlchemy
# b) `session.disconnect()`
# c) `session.terminate()`
# d) `session.end()`
#
# ---
#
# #### **11. Что происходит при вызове `session.rollback()`?**
# a) Удаляются все данные в таблице
# b) <u>Все изменения в текущей транзакции отменяются</u>
# c) Сессия закрывается
# d) Перезапускается соединение с базой
#
# ---
#
# #### **12. Для чего используется `metadata.create_all()`?**
# a) <u>Создает таблицы в базе данных на основе моделей</u>
# b) Выполняет миграции
# c) Обновляет индексы в таблицах
# d) Удаляет существующие данные в таблицах
#
# ---
#
# #### **13. Какой метод позволяет выполнить SQL-запрос напрямую?**
# a) `session.raw_query()`
# b) <u>`session.execute()`</u>
# c) `session.run_sql()`
# d) `session.query_raw()`
#
# ---
#
# #### **14. Какой параметр используется для задания внешнего ключа?**
# a) <u>`ForeignKey`</u>
# b) `relationship`
# c) `foreign_key=True`
# d) `primary_key=False`
#
# ---
#
# #### **15. Какой метод используется для обновления записи?**
# a) <u>`session.update()`</u>
# b) `session.merge()`
# c) `session.modify()`
# d) `session.edit()`
#
# ---
#
# #### **16. Как включить автоматическую обработку миграций с SQLAlchemy?**
# a) <u>Использовать Alembic</u>
# b) Включить `auto_migrations=True`
# c) Использовать встроенные миграции SQLAlchemy
# d) Настроить `Session` для миграций
#
# ---
#
# #### **17. Как создать уникальный индекс в SQLAlchemy?**
# a) <u>Добавить параметр `unique=True` к `Column`</u>
# b) Использовать `create_unique_index()`
# c) Добавить параметр `index=True` к `Column`
# d) Применить метод `session.add_index()`
#
# ---
#
# #### **18. Что возвращает метод `session.commit()`?**
# a) Успешность выполнения транзакции
# b) <u>None</u>
# c) Объект запроса
# d) Количество измененных строк
#
# ---
#
# #### **19. Какой метод используется для асинхронного подключения к базе в FastAPI?**
# a) `connect_async()`
# b) <u>`async_engine.connect()`</u>
# c) `async_session.connect()`
# d) `await async_engine.begin()`
#
# ---
#
# #### **20. Какой параметр в `relationship` задает поведение при удалении записи?**
# a) `cascade`
# b) `lazy`
# c) `delete_rule`
# d) <u>`on_delete`</u>
#
# ---
#
# #### **21. Что происходит при использовании `lazy='dynamic'` в `relationship()`?**
# a) Все связанные записи загружаются сразу
# b) <u>Запрос к связанным данным выполняется только при обращении к ним</u>
# c) Запросы к данным блокируются до завершения транзакции
# d) Данные кэшируются на уровне модели
#
# ---
#
# #### **22. Как определить связь "многие-ко-многим" в SQLAlchemy?**
# a) Использовать `relationship` с параметром `many_to_many=True`
# b) <u>Создать вспомогательную таблицу и связать через `relationship`</u>
# c) Использовать параметр `multi_key` в `ForeignKey`
# d) Использовать `dynamic_relationship`
#
# ---
#
# #### **23. Что делает метод `session.flush()`?**
# a) Закрывает сессию и сохраняет данные
# b) Сбрасывает кэш сессии
# c) <u>Применяет изменения в базе данных без завершения транзакции</u>
# d) Удаляет все объекты, связанные с сессией
#
# ---
#
# #### **24. Какой объект отвечает за управление таблицами и их связями в SQLAlchemy?**
# a) `Session`
# b) `Base`
# c) <u>`MetaData`</u>
# d) `Engine`
#
# ---
#
# #### **25. Какой параметр указывается в `Column`, чтобы задать автоматическое увеличение значения (например, для `id`)?**
# a) `increment=True`
# b) <u>`autoincrement=True`</u>
# c) `auto_increase=True`
# d) `serial=True`
#
# ---
#
# #### **26. Какую функцию необходимо вызвать для асинхронной работы с базой в FastAPI?**
# a) `create_async_session()`
# b) `asyncio.run()`
# c) <u>`create_async_engine()`</u>
# d) `initialize_async_session()`
#
# ---
#
# #### **27. Что делает параметр `cascade="all, delete-orphan"` в `relationship()`?**
# a) Удаляет записи, не имеющие связей с другими таблицами
# b) <u>Удаляет только связанные записи при удалении родительской записи</u>
# c) Удаляет таблицу целиком при удалении связей
# d) Создает уникальные индексы в таблице
#
# ---
#
# #### **28. Какой метод используется для выполнения групповых операций над данными?**
# a) `session.group()`
# b) `session.aggregate()`
# c) `func` из SQLAlchemy
# d) <u>`group_by()`</u>
#
# ---
#
# #### **29. Как можно ускорить выполнение запросов в SQLAlchemy?**
# a) Использовать индексы и `joined` загрузку данных
# b) Отключить `autocommit`
# c) Уменьшить количество `session.add()` вызовов
# d) <u>Все вышеперечисленные</u>
#
# ---
#
# #### **30. Какой способ подключения к базе данных лучше всего использовать для микросервисной архитектуры?**
# a) Глобальный объект `Session`
# b) Локальный объект `Session` для каждого запроса
# c) <u>Пул соединений через `engine`</u>
# d) Асинхронный `session`
